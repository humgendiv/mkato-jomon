# %%
import matplotlib.pyplot as plt

# The user has uploaded another file for similar processing. Let's apply the same approach to extract the data.
file_path_t5 = '/home/mkato/hdd_data/data/0-0-raw_vcf/stats/T5_stats.txt'

quality_values_t5 = []
snp_counts_t5 = []

with open(file_path_t5, 'r') as file:
    lines = file.readlines()
    # Extracting data from line 43 onwards
    for line in lines[42:]:  # Line numbers in Python are zero-indexed
        if line.startswith("QUAL"):
            parts = line.split()
            try:
                # Extracting the Quality and number of SNPs
                quality_t5 = float(parts[2])
                snp_count_t5 = int(parts[3])
                quality_values_t5.append(quality_t5)
                snp_counts_t5.append(snp_count_t5)
            except ValueError:
                # Skip lines with non-numeric values
                continue

# Now plotting the histogram for Quality values and a line plot for number of SNPs for T5
plt.figure(figsize=(12, 6))

# Histogram for Quality values
plt.subplot(1, 2, 1)
plt.hist(quality_values_t5, bins=50, color='blue', edgecolor='black')
plt.title('Histogram of Quality Values for T5')
plt.xlabel('Quality')
plt.ylabel('Frequency')
plt.grid(True)

# Line plot for number of SNPs
plt.subplot(1, 2, 2)
plt.plot(quality_values_t5, snp_counts_t5, marker='o', color='purple', linestyle='-')
plt.title('Quality vs. Number of SNPs for T5')
plt.xlabel('Quality')
plt.ylabel('Number of SNPs')
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# The user has uploaded another file for similar processing. Let's apply the same approach to extract the data.
file_path_t5 = '/home/mkato/hdd_data/data/0-0-raw_vcf/stats/I4_stats.txt'

quality_values_t5 = []
snp_counts_t5 = []

with open(file_path_t5, 'r') as file:
    lines = file.readlines()
    # Extracting data from line 43 onwards
    for line in lines[42:]:  # Line numbers in Python are zero-indexed
        if line.startswith("QUAL"):
            parts = line.split()
            try:
                # Extracting the Quality and number of SNPs
                quality_t5 = float(parts[2])
                snp_count_t5 = int(parts[3])
                quality_values_t5.append(quality_t5)
                snp_counts_t5.append(snp_count_t5)
            except ValueError:
                # Skip lines with non-numeric values
                continue

# Now plotting the histogram for Quality values and a line plot for number of SNPs for T5
plt.figure(figsize=(12, 6))

# Histogram for Quality values
plt.subplot(1, 2, 1)
plt.hist(quality_values_t5, bins=50, color='blue', edgecolor='black')
plt.title('Histogram of Quality Values for I4')
plt.xlabel('Quality')
plt.ylabel('Frequency')
plt.grid(True)

# Line plot for number of SNPs
plt.subplot(1, 2, 2)
plt.plot(quality_values_t5, snp_counts_t5, marker='o', color='purple', linestyle='-')
plt.title('Quality vs. Number of SNPs for I4')
plt.xlabel('Quality')
plt.ylabel('Number of SNPs')
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# The user has uploaded another file for similar processing. Let's apply the same approach to extract the data.
file_path_t5 = '/home/mkato/hdd_data/data/0-0-raw_vcf/stats/FM020_stats.txt'

quality_values_t5 = []
snp_counts_t5 = []

with open(file_path_t5, 'r') as file:
    lines = file.readlines()
    # Extracting data from line 43 onwards
    for line in lines[42:]:  # Line numbers in Python are zero-indexed
        if line.startswith("QUAL"):
            parts = line.split()
            try:
                # Extracting the Quality and number of SNPs
                quality_t5 = float(parts[2])
                snp_count_t5 = int(parts[3])
                quality_values_t5.append(quality_t5)
                snp_counts_t5.append(snp_count_t5)
            except ValueError:
                # Skip lines with non-numeric values
                continue

# Now plotting the histogram for Quality values and a line plot for number of SNPs for T5
plt.figure(figsize=(12, 6))

# Histogram for Quality values
plt.subplot(1, 2, 1)
plt.hist(quality_values_t5, bins=50, color='blue', edgecolor='black')
plt.title('Histogram of Quality Values for FM020')
plt.xlabel('Quality')
plt.ylabel('Frequency')
plt.grid(True)

# Line plot for number of SNPs
plt.subplot(1, 2, 2)
plt.plot(quality_values_t5, snp_counts_t5, marker='o', color='purple', linestyle='-')
plt.title('Quality vs. Number of SNPs for FM020')
plt.xlabel('Quality')
plt.ylabel('Number of SNPs')
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# The user has uploaded another file for similar processing. Let's apply the same approach to extract the data.
file_path_t5 = '/home/mkato/hdd_data/data/0-0-raw_vcf/stats/F23_stats.txt'

quality_values_t5 = []
snp_counts_t5 = []

with open(file_path_t5, 'r') as file:
    lines = file.readlines()
    # Extracting data from line 43 onwards
    for line in lines[42:]:  # Line numbers in Python are zero-indexed
        if line.startswith("QUAL"):
            parts = line.split()
            try:
                # Extracting the Quality and number of SNPs
                quality_t5 = float(parts[2])
                snp_count_t5 = int(parts[3])
                quality_values_t5.append(quality_t5)
                snp_counts_t5.append(snp_count_t5)
            except ValueError:
                # Skip lines with non-numeric values
                continue

# Now plotting the histogram for Quality values and a line plot for number of SNPs for T5
plt.figure(figsize=(12, 6))

# Histogram for Quality values
plt.subplot(1, 2, 1)
plt.hist(quality_values_t5, bins=50, color='blue', edgecolor='black')
plt.title('Histogram of Quality Values for F23')
plt.xlabel('Quality')
plt.ylabel('Frequency')
plt.grid(True)

# Line plot for number of SNPs
plt.subplot(1, 2, 2)
plt.plot(quality_values_t5, snp_counts_t5, marker='o', color='purple', linestyle='-')
plt.title('Quality vs. Number of SNPs for F23')
plt.xlabel('Quality')
plt.ylabel('Number of SNPs')
plt.grid(True)

plt.tight_layout()
plt.show()
